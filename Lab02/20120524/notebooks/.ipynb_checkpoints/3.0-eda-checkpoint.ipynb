# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
studentID = 20120524
your_continent = "asia"
file_name = "_".join([str(studentID), str(your_continent)]) + "_processed.csv"
cleaned_df = pd.read_csv(os.path.join("../data/processed", file_name))
# raise NotImplementedError()

# %%
# TEST
cleaned_df.dtypes
# Out:
# Total Population                              float64
# Female Population                             float64
# Male Population                               float64
# Birth Rate                                    float64
# Death Rate                                    float64
# Compulsory Education Dur.                     float64
# Employment in Industry(%)                     float64
# Employment in Agriculture(%)                  float64
# Female Employment in Agriculture(%)           float64
# Female Employment in Industry(%)              float64
# Unemployment(%)                               float64
# GDP in USD                                    float64
# National Income per Capita                    float64
# Net income from Abroad                        float64
# Agriculture value added(in USD)               float64
# Electric Power Consumption(kWH per capita)    float64
# Renewable Energy Consumption (%)              float64
# ...

# %%
# TEST
cleaned_df.shape
# Out:
# (1316, 25)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')
def mode (column):
    return column.mode().iloc[0]
def quantile_25 (column):
    return column.quantile(0.25)
def quantile_50 (column):
    return column.quantile(0.5)
def quantile_75 (column):
    return column.quantile(0.75)
def r(column):
    return column.max() - column.min()
def iqr (column):
    return column.quantile(0.75) - column.quantile(0.25)
def CoV(column):
    return column.std() / column.mean() * 100
    
# YOUR CODE HERE
df_copy.describe()
df_copy.agg(['mean', 'median', mode, quantile_25, quantile_50, quantile_75, r, iqr, 'var', 'std', 
                       CoV, 'skew', 'kurtosis', 'sem'])
# raise NotImplementedError()
# Out:
#              Total Population  Female Population  Male Population  Birth Rate  \
# mean             9.020217e+07       4.433594e+07     4.586623e+07   20.700378
# median           1.822701e+07       9.013542e+06     9.061772e+06   20.216500
# mode             1.274450e+08       1.249510e+05     1.332570e+05   20.700378
# quantile_25      4.382818e+06       2.121473e+06     2.311564e+06   15.272250
# quantile_50      1.822701e+07       9.013542e+06     9.061772e+06   20.216500
# quantile_75      6.135766e+07       3.051728e+07     3.080141e+07   24.321000
# r                1.416915e+09       6.914036e+08     7.310472e+08   46.973000
# iqr              5.697485e+07       2.839581e+07     2.848984e+07    9.048750
# var              6.499019e+16       1.537660e+16     1.714697e+16   59.169564
# std              2.549317e+08       1.240024e+08     1.309465e+08    7.692176
# CoV              2.826226e+02       2.796883e+02     2.854965e+02   37.159589
# ...

# %% [markdown]
# **TODO**: Give your obervation here
#
# - mean: Biểu thị giá trị trung bình của tập dữ liệu. Nó đưa ra ý tưởng về xu hướng trung tâm của dữ liệu
# - median: Giá trị ở giữa của một tập dữ liệu đã được sắp xếp theo thứ tự tăng dần. Nó phân chia dữ liệu thành hai phần bằng nhau, với 50% dữ liệu nhỏ hơn và 50% dữ liệu lớn hơn nó. Median được sử dụng để đo lường giá trị trung tâm của tập dữ liệu và không bị ảnh hưởng bởi các giá trị ngoại lai.
# - mode: Giá trị xuất hiện nhiều nhất trong tập dữ liệu. Nó được sử dụng để xác định giá trị phổ biến nhất hoặc xu hướng của dữ liệu
# - quantile_25: Giá trị mà 25% dữ liệu nhỏ hơn và 75% dữ liệu lớn hơn nó. Nó giúp xác định phần trăm dữ liệu nằm dưới một ngưỡng nhất định
# - quantile_50: Tương đương với median và chia tập dữ liệu thành hai phần bằng nhau.
# - quantile_75: Giá trị mà 75% dữ liệu nhỏ hơn và 25% dữ liệu lớn hơn nó. Nó giúp xác định phần trăm dữ liệu nằm trên một ngưỡng nhất định.
# - r(range): Sự khác biệt giữa giá trị lớn nhất và giá trị nhỏ nhất trong tập dữ liệu. Nó đo lường sự biến động tối đa của dữ liệu
# - iqr: Khoảng cách giữa quantile_75 và quantile_25. Nó đo lường phạm vi của 50% giá trị trung tâm của dữ liệu và được sử dụng để xác định sự biến động của dữ liệu trung tâm.
# - var: Đại lượng thống kê dùng để đo độ biến đổi của một tập dữ liệu. Nó tính bằng cách lấy trung bình của bình phương của độ lệch của mỗi giá trị dữ liệu so với giá trị trung bình của tập dữ liệu. Variance càng cao thì dữ liệu càng phân tán và không đồng đều.
# - std: Cung cấp thông tin về sự phân tán hoặc lan truyền của dữ liệu. Độ lệch chuẩn cao hơn biểu thị phạm vi giá trị rộng hơn, trong khi độ lệch chuẩn thấp hơn biểu thị phạm vi giá trị hẹp hơn
# - CoV: Đại lượng thống kê dùng để so sánh mức độ biến thiên giữa các tập dữ liệu có đơn vị đo lường khác nhau. Nó tính bằng cách chia độ lệch chuẩn cho giá trị trung bình của tập dữ liệu và nhân 100 để đưa về dạng phần trăm. Coefficient of Variation càng cao thì mức độ biến thiên càng lớn.
# - skewness: Đo lường sự bất đối xứng của phân bố. Độ lệch dương cho biết đuôi dài hơn ở bên phải, trong khi độ lệch âm cho thấy đuôi dài hơn ở bên trái
# - kurtosis: Đo lường mức đỉnh của phân phối. Độ nhọn cao hơn cho thấy đỉnh sắc nét hơn, trong khi độ nhọn thấp hơn cho thấy sự phân bố phẳng hơn
# - sem: Đại lượng thống kê dùng để đo độ chính xác của một ước lượng thống kê. Nó tính bằng cách chia độ lệch chuẩn cho căn bậc hai của kích thước mẫu. Standard Error càng nhỏ thì ước lượng thống kê càng chính xác.
# ...

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()
df_copy = df_copy.drop(['Year', 'Country'], axis='columns')
corr_mat = df_copy.corr()
plt.imshow(corr_mat, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(corr_mat.columns)), corr_mat.columns, rotation=90)
plt.yticks(range(len(corr_mat.columns)), corr_mat.columns)
plt.title('Correlation Matrix')
plt.show()
# raise NotImplementedError()

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population ?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is large.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# Top 10 quốc gia với dân số đông nhất vào năm 2022
df_copy = cleaned_df.copy()
df_2022 = df_copy.loc[df_copy["Year"] == 2022]
df_2022_TotatPopulation_descending = df_2022.sort_values("Total Population", ascending=False).reset_index()
df_2022_Top10Largest_TotatPopulation = df_2022_TotatPopulation_descending.head(10).drop(['index', 'Year', 'Country'], axis='columns')
corr_mat = df_2022_Top10Largest_TotatPopulation.corr()
# Xoá các đặc điểm không thay đổi 
for col in corr_mat.columns:
    if pd.isna(corr_mat[col]).all():
        corr_mat = corr_mat.drop(col, axis='columns')
        corr_mat = corr_mat.drop(col)
corr_mat
# Out:
#                                  Total Population  Female Population  \
# Total Population                         1.000000           0.999950
# Female Population                        0.999950           1.000000
# Male Population                          0.999955           0.999810
# Compulsory Education Dur.               -0.239792          -0.239677
# Unemployment(%)                          0.190084           0.188182
# GDP in USD                               0.730157           0.735478
# Net income from Abroad                  -0.823984          -0.828711
# Agriculture value added(in USD)          0.898937           0.902096
# School enrollment, primary              -0.050893          -0.052065
# School enrollment, tertiary              0.560686           0.565483
# Primary completion rate                 -0.244437          -0.244462
#
#                                  Male Population  Compulsory Education Dur.  \
# ...

# %% [markdown]
# **YOUR ANSWER**: Ở 10 quốc gia đông dân số nhất vào năm 2022, ta thấy:
# - Các đặc điểm Birth Rate, Death Rate, Employment in Industry(%), Employment in Agriculture(%), Female Employment in Agriculture(%), Female Employment in Industry(%), National Income per Capita, Electric Power Consumption(kWH per capita), Renewable Energy Consumption (%), Fossil Fuel Consumption (%), Male life expectancy, Female life expectancy không thay đổi nên loại bỏ khỏi bảng hệ số tương quan
# - Total Population có mối quan hệ tuyến tính dương với Female Population; Male Population; Unemployment(%); GDP in USD; Agriculture value added(in USD); School enrollment, tertiary vì có hệ số tương quan dương
# - Total Population, Female Population, Male Population, Agriculture value added(in USD) là nhóm đặc điểm có hệ số tương quan gần 1 nên có mối quan hệ tuyến tính dương mạnh giữa các biến
# - Total Population có mối quan hệ tuyến tính âm với Compulsory Education Dur; Net income from Abroad; Primary completion rate vì có hệ số tương quan âm
# - Total Population có mối quan hệ tuyến tính âm mạnh với Net income from Abroad vì có hệ số tương quan gần -1
# - Total Population không có mối quan hệ tuyến tính với School enrollment, primary vì hệ số tương quan gần 0 nên mối quan hệ rất tuyến tính rất yếu coi như không có
# - Ta có các nhận xét tương tự với các đặc điểm còn lại dựa vào hệ số tương quan âm hay dương, gần 1 hay -1 hoặc gần 0.

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# YOUR CODE HERE
# Top 10 quốc gia với dân số ít nhất vào năm 2022
df_2022_TotatPopulation_ascending = df_2022.sort_values("Total Population", ascending=True).reset_index()
df_2022_Top10Smallest_TotatPopulation = df_2022_TotatPopulation_ascending.head(10).drop(['index', 'Year', 'Country'], axis='columns')
corr_mat = df_2022_Top10Smallest_TotatPopulation.corr()
# Xoá các đặc điểm không thay đổi 
for col in corr_mat.columns:
    if pd.isna(corr_mat[col]).all():
        corr_mat = corr_mat.drop(col, axis='columns')
        corr_mat = corr_mat.drop(col)
corr_mat
# Out:
#                                  Total Population  Female Population  \
# Total Population                         1.000000           0.938489
# Female Population                        0.938489           1.000000
# Male Population                          0.956186           0.796278
# Compulsory Education Dur.                0.460577           0.432720
# Unemployment(%)                          0.187557           0.489978
# GDP in USD                              -0.051557          -0.204430
# Net income from Abroad                   0.411269           0.335628
# Agriculture value added(in USD)         -0.107001          -0.173990
# School enrollment, primary              -0.095573          -0.147672
# School enrollment, tertiary              0.446774           0.573247
# Primary completion rate                  0.515166           0.588702
#
#                                  Male Population  Compulsory Education Dur.  \
# ...

# %% [markdown]
# **YOUR ANSWER**: Ở 10 quốc gia ít dân số nhất vào năm 2022, ta thấy:
# - Các đặc điểm Birth Rate, Death Rate, Employment in Industry(%), Employment in Agriculture(%), Female Employment in Agriculture(%), Female Employment in Industry(%), National Income per Capita, Electric Power Consumption(kWH per capita), Renewable Energy Consumption (%), Fossil Fuel Consumption (%), Male life expectancy, Female life expectancy không thay đổi nên loại bỏ khỏi bảng hệ số tương quan
# - Total Population có mối quan hệ tuyến tính dương với Female Population; Male Population; Compulsory Education Dur; Unemployment(%); Net income from Abroad; School enrollment, tertiary; Primary completion rate vì có hệ số tương quan dương
# - Total Population, Female Population, Male Population là nhóm đặc điểm có hệ số tương quan gần 1 nên có mối quan hệ tuyến tính dương mạnh giữa các biến
# - Total Population có mối quan hệ tuyến tính âm với GDP in USD; Agriculture value added(in USD); School enrollment, primary vì có hệ số tương quan âm nhưng hệ số tương quan gần 0 nên mối quan hệ tuyến tính rất yếu coi như không có
# - Ta có các nhận xét tương tự với các đặc điểm còn lại dựa vào hệ số tương quan âm hay dương, gần 1 hay -1 hoặc gần 0.
#
# Example: Is that possible to drop any features that have less effect?
# Answer: Possible

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE
avg_birthrate_df = df_copy.groupby('Country')['Birth Rate'].mean().reset_index()
avg_birthrate_df.sort_values('Birth Rate', ascending=False).reset_index()
# raise NotImplementedError()
# Out:
#     index                    Country  Birth Rate
# 0       0                Afghanistan   42.601621
# 1      46                Yemen, Rep.   36.332442
# 2      14                       Iraq   33.036156
# 3      31                   Pakistan   32.258621
# 4      39                 Tajikistan   30.229478
# 5      23                    Lao PDR   28.321871
# 6      17                     Jordan   27.545978
# 7      38       Syrian Arab Republic   26.834906
# 8      32                Philippines   25.937299
# 9      29                      Nepal   25.460692
# 10      7                   Cambodia   24.934049
# 11     42               Turkmenistan   24.296656
# 12     22            Kyrgyz Republic   23.871442
# 13      4                 Bangladesh   23.575621
# 14     35               Saudi Arabia   23.032335
# 15     44                 Uzbekistan   22.878585
# 16     11                      India   22.529692
# 17     30                       Oman   22.427585
# ...

# %%
# You can just construct plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(12, 6))
plt.bar(avg_birthrate_df["Country"], avg_birthrate_df["Birth Rate"])
plt.title('Average Birth Rate by Country')
plt.xlabel('Country')
plt.ylabel('Average Birth Rate')
plt.xticks(rotation=90)
plt.show()
# raise NotImplementedError()

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE
avg_deathrate_df = df_copy.groupby('Country')['Death Rate'].mean().reset_index()
avg_deathrate_df.sort_values('Death Rate', ascending=False).reset_index()
# raise NotImplementedError()
# Out:
#     index                    Country  Death Rate
# 0      34         Russian Federation   14.026539
# 1      10                    Georgia   11.875182
# 2       0                Afghanistan    9.438110
# 3      28                    Myanmar    9.436503
# 4       1                    Armenia    9.181610
# 5      18                 Kazakhstan    9.095825
# 6      19  Korea, Dem. People’s Rep.    9.076146
# 7      16                      Japan    9.047967
# 8      23                    Lao PDR    8.587217
# 9      31                   Pakistan    7.937467
# 10     11                      India    7.793360
# 11     29                      Nepal    7.560860
# 12     12                  Indonesia    7.553217
# 13      5                     Bhutan    7.360503
# 14     37                  Sri Lanka    7.331146
# 15      7                   Cambodia    7.300182
# 16      9                     Cyprus    6.880860
# 17     27                   Mongolia    6.826860
# ...

# %%
# You can just construct plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(12, 6))
plt.bar(avg_deathrate_df["Country"], avg_deathrate_df['Death Rate'])
plt.title('Average Death Rate by Country')
plt.xlabel('Country')
plt.ylabel('Average Death Rate')
plt.xticks(rotation=90)
plt.show()
# raise NotImplementedError()

# %% [markdown]
# **TODO**: Give your obervation here
# - Quốc gia có Birth Rate cao nhất là Afghanistan bằng 42.601621
# - Quốc gia có Birth Rate thấp nhất là Japan bằng 8.910728
# - Quốc gia có Death Rate cao nhất là Russian Federation bằng 14.026539
# - Quốc gia có Deadth Rate thấp nhất là United Arab Emirates bằng 1.727467
# - 5 quốc gia có sự phát triển lao động, mức độ tăng trưởng dân số nhanh và có thể ảnh hưởng đến sự phát triển kinh tế và xã hội là Afghanistan; Yemen, Rep; Iraq; Pakistan; Tajikistan
# - 5 quốc gia có sự phát triển lao động, mức độ tăng trưởng dân số chậm là Japan; Korea, Rep; Singapore; Russian Federation; Cyprus
# - 5 quốc gia có tình hình sức khỏe, chất lượng cuộc sống và hệ thống y tế kém là Russian Federation; Georgia; Afghanistan; Myanmar; Armenia
# - 5 quốc gia có tình hình sức khỏe, chất lượng cuộc sống và hệ thống y tế tốt là United Arab Emirates; Qatar; Kuwait; Bahrain; Oman

# %% [markdown]
# ## Making your own question 01? (1.5 points)
# **A possible question is:** Tốc độ gia tăng dân số của cả lục địa qua từng năm như thế nào
#
# **Answering this question will** Giúp chúng ta thấy được tốc độ gia tăng dân số và những dự đoán về chính sách dân số tương lai được áp dụng trên lục địa

# %% [markdown]
# **YOUR ANSWER HERE**: Tôi sẽ xem xét tỷ lệ gia tăng dân số của tất cả quốc gia trên lục địa qua các năm. Tức là tỉ lệ giữa Total Population của năm sau và năm trước, với năm đầu tiên xem xét là 1995

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
TotalPopulation_df = df_copy.groupby('Year')['Total Population'].sum().reset_index()
TotalPopulation_df["Increase Rate (%)"] = TotalPopulation_df['Total Population'] /  \
TotalPopulation_df['Total Population'].shift(periods=1, fill_value=TotalPopulation_df["Total Population"][0]) * 100 - 100
TotalPopulation_df
# Out:
#     Year  Total Population  Increase Rate (%)
# 0   1995      3.586191e+09           0.000000
# 1   1996      3.639613e+09           1.489635
# 2   1997      3.692934e+09           1.465037
# 3   1998      3.745680e+09           1.428283
# 4   1999      3.796927e+09           1.368161
# 5   2000      3.847215e+09           1.324451
# 6   2001      3.897132e+09           1.297478
# 7   2002      3.946036e+09           1.254885
# 8   2003      3.993728e+09           1.208589
# 9   2004      4.040577e+09           1.173071
# 10  2005      4.087122e+09           1.151946
# 11  2006      4.133534e+09           1.135550
# 12  2007      4.179330e+09           1.107922
# 13  2008      4.225422e+09           1.102861
# 14  2009      4.271682e+09           1.094800
# 15  2010      4.317968e+09           1.083547
# 16  2011      4.364920e+09           1.087379
# 17  2012      4.413042e+09           1.102450
# 18  2013      4.460491e+09           1.075210
# ...

# %% [markdown]
# **My observation**: Tốc độ gia tăng dân số của lục địa asia có xu hướng giảm qua từng năm, vấn đề khủng hoảng dân số không quá thách thức

# %% [markdown]
# ## Making your own question 02? (1.5 points)
# **A possible question is:** Tỉ lệ thất nghiệp trung bình trong tất cả các năm của từng quốc gia như thế nào
#
# **Answering this question will** Giúp chúng ta thấy được tình trạng thất nghiệp của mỗi quốc gia từ đó dự đoán thị trường việc làm ở các quốc gia asia

# %% [markdown]
# **YOUR ANSWER HERE**: Tôi sẽ xem xét tỷ lệ thất nghiệp trung bình qua tất cả các năm của từng quốc gia trên lục địa

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
unemployment_df = df_copy.groupby('Country')['Unemployment(%)'].mean()
unemployment_df.sort_values(ascending=True).reset_index()
# Out:
#                       Country  Unemployment(%)
# 0                       Qatar         0.511571
# 1                    Cambodia         0.722929
# 2                     Myanmar         1.121756
# 3                     Bahrain         1.185679
# 4                    Thailand         1.248000
# 5                      Kuwait         1.717071
# 6                     Vietnam         1.902393
# 7                    Pakistan         2.007357
# 8                     Lao PDR         2.087571
# 9        United Arab Emirates         2.458964
# 10                     Bhutan         2.693179
# 11            Kyrgyz Republic         2.863464
# 12  Korea, Dem. People’s Rep.         2.895393
# 13                   Malaysia         3.334857
# 14                Philippines         3.336429
# 15                Korea, Rep.         3.478143
# 16                       Oman         3.621357
# 17                      Japan         3.913607
# 18                 Bangladesh         3.979821
# ...

# %% [markdown]
# **My observation**: Qatar có tỉ lệ thất nghiệp thấp nhất, khoảng 0.51%, thị trường việc làm rộng lớn, thiếu nhân lực. Jordan có tỉ lệ thất nghiệp cao nhất, khoảng 14.6%
